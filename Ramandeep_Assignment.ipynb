# %% [markdown]
# # MARKDOWN CELLS

# %% [markdown]
# <a id="top"></a>
# # This is Heading Level 1
# ## This is Heading Level 2

# %% [markdown]
# ### Font Effects ###
# *Italics*
#
# **Bold**

# %% [markdown]
# ### CheckBox ###
# - [x] Checkbox
# - [ ] To do
#
# ### Ordered List ###
# 1. Checkbox
#    1. Done
#    2. Done
# 3. Ordered List
#    1. Done
# 5. Unordered List
#    1. Done
#
# ### Unordered List ###
# - Checkbox
# - Ordered List
# - Unordered List

# %% [markdown]
# ### Table Cell ###
#
# |Left  |Right  |Left|
# |:-----|------:|:-----|
# |1     |      1|3     |
# |2     |      6|2     |

# %% [markdown]
# ### Image Link ###
# [GMAIL LOGO](https://ssl.gstatic.com/ui/v1/icons/mail/rfr/logo_gmail_lockup_default_1x_r5.png)

# %% [markdown]
# ### Local Image ###
#
#
# ![sunshine.jpg](attachment:4bc17bd3-a417-4e2d-bf05-ef61ba8f7a76.jpg)

# %% [markdown]
# ### Anchor Cell ###
# [Return to Top](#top) ### Not Working ###

# %% [markdown]
# ### Q1. A car with a full tank of gas drives 80 miles per hour for 3 hours before running out of gas. How many miles can the car go per tank? ###

# %%
80*3
# Out:
# 240

# %% [markdown]
# ### Q2 A runner travels a half marathon (13.1 miles) in 3 hours. How fast was this runner going in miles per hour? ###

# %%
(round(13.1/3,2))
# Out:
# 4.37

# %% [markdown]
# ### Q3 The spread of a virus is exponential. If 5 people are infected and each person infects 2 other people, how many people have been infected after 5 rounds of infection? ###

# %%
5*(2**5)
# Out:
# 160

# %% [markdown]
# ### BONUS QUESTION 1 ###

# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
fig = plt.figure()
ax = fig.add_subplot(111)
ax.plot([1, 2, 3], [80, 160, 240], color='lightblue', marker='o', linewidth=2)
# Add labels and title
plt.xlabel('Time (hours)')
plt.ylabel('Distance (miles)')
plt.title('Distance vs Time for a Car with a Full Tank of Gas')
ax.set_xlim(0, 5)
plt.show()
